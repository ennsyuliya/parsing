# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\enns\anaconda3\lib\site-packages (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\enns\anaconda3\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\enns\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\enns\anaconda3\lib\site-packages (from requests) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\enns\anaconda3\lib\site-packages (from requests) (2.0.4)

# %%
import requests
import json

# %% [markdown]
# 1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
import requests
import time
import json

def get_data(url: str) -> dict:
    while True:
        time.sleep(1)
        response = requests.get(url)
        if response.status_code == 200:
            break
    return response.json()

username = input('Введите username: ')
username = 'mmingalov' if username == '' else username
url = 'https://api.github.com/users/'+username+'/repos'

response = get_data(url)
print('Получен результат')
print(response)

repo = []
for itm in response:
    repo.append(itm['name'])
print(f'Список репозиториев пользователя {username}')
print(repo)

with open('1_1_repo.json', 'w') as f:
    json_repo = json.dump(repo, f)
# Out:
# Получен результат
# [{'id': 272902655, 'node_id': 'MDEwOlJlcG9zaXRvcnkyNzI5MDI2NTU=', 'name': 'autocalc', 'full_name': 'mmingalov/autocalc', 'private': False, 'owner': {'login': 'mmingalov', 'id': 55125744, 'node_id': 'MDQ6VXNlcjU1MTI1NzQ0', 'avatar_url': 'https://avatars.githubusercontent.com/u/55125744?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mmingalov', 'html_url': 'https://github.com/mmingalov', 'followers_url': 'https://api.github.com/users/mmingalov/followers', 'following_url': 'https://api.github.com/users/mmingalov/following{/other_user}', 'gists_url': 'https://api.github.com/users/mmingalov/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mmingalov/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mmingalov/subscriptions', 'organizations_url': 'https://api.github.com/users/mmingalov/orgs', 'repos_url': 'https://api.github.com/users/mmingalov/repos', 'events_url': 'https://api.github.com/users/mmingalov/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mmingalov/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/mmingalov/autocalc', 'description': 'calculator of prices for auto import from Japan to Russia', 'fork': False, 'url': 'https://api.github.com/repos/mmingalov/autocalc', 'forks_url': 'https://api.github.com/repos/mmingalov/autocalc/forks', 'keys_url': 'https://api.github.com/repos/mmingalov/autocalc/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/mmingalov/autocalc/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/mmingalov/autocalc/teams', 'hooks_url': 'https://api.github.com/repos/mmingalov/autocalc/hooks', 'issue_events_url': 'https://api.github.com/repos/mmingalov/autocalc/issues/events{/number}', 'events_url': 'https://api.github.com/repos/mmingalov/autocalc/events', 'assignees_url': 'https://api.github.com/repos/mmingalov/autocalc/assignees{/user}', 'branches_url': 'https://api.github.com/repos/mmingalov/autocalc/branches{/branch}', 'tags_url': 'https://api.github.com/repos/mmingalov/autocalc/tags', 'blobs_url': 'https://api.github.com/repos/mmingalov/autocalc/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/mmingalov/autocalc/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/mmingalov/autocalc/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/mmingalov/autocalc/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/mmingalov/autocalc/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/mmingalov/autocalc/languages', 'stargazers_url': 'https://api.github.com/repos/mmingalov/autocalc/stargazers', 'contributors_url': 'https://api.github.com/repos/mmingalov/autocalc/contributors', 'subscribers_url': 'https://api.github.com/repos/mmingalov/autocalc/subscribers', 'subscription_url': 'https://api.github.com/repos/mmingalov/autocalc/subscription', 'commits_url': 'https://api.github.com/repos/mmingalov/autocalc/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/mmingalov/autocalc/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/mmingalov/autocalc/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/mmingalov/autocalc/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/mmingalov/autocalc/contents/{+path}', 'compare_url': 'https://api.github.com/repos/mmingalov/autocalc/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/mmingalov/autocalc/merges', 'archive_url': 'https://api.github.com/repos/mmingalov/autocalc/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/mmingalov/autocalc/downloads', 'issues_url': 'https://api.github.com/repos/mmingalov/autocalc/issues{/number}', 'pulls_url': 'https://api.github.com/repos/mmingalov/autocalc/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/mmingalov/autocalc/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/mmingalov/autocalc/notifi ...
# Список репозиториев пользователя mmingalov
# ['autocalc', 'geekbrains-algorithms-structures-python', 'geekbrains-data-analysis-alg', 'geekbrains-db', 'geekbrains-db-for-analysts', 'geekbrains-final-project', 'geekbrains-hadoop-introduction', 'geekbrains-math', 'geekbrains-methods-data-collection-from-internet', 'geekbrains-ml-business', 'geekbrains-python-data-science', 'geekbrains-recommend-systems', 'geekbrains-spark', 'geekbrains-spark-streaming', 'geekbrains-tableau', 'geekbrains-theory-of-chances', 'hello-world', 'kc-airflow', 'kc-big-ML', 'kc-databases', 'kc-hadoop', 'micromine-lab-protocols', 'mmingalov', 'VBM']

# %% [markdown]
# 2. Изучить список открытых API (https://www.programmableweb.com/category/all/apis). Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.

# %%
url = 'https://api.vk.com'

method = 'friends.getOnline'

user_id = '474319172'

access_token = ''

responce = requests.get(f'{url}/method/{method}?v=5.52&access_token={access_token}')

with open('data.json', 'w') as f:
    json.dump(responce.json(), f)

print(responce.json())

{'response': [47207942]}
# Out:
# {'error': {'error_code': 5, 'error_msg': 'User authorization failed: no access_token passed.', 'request_params': [{'key': 'v', 'value': '5.52'}, {'key': 'method', 'value': 'friends.getOnline'}, {'key': 'oauth', 'value': '1'}]}}
# {'response': [47207942]}
